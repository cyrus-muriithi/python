# %% [markdown]
# # Data Visualization using Python

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
os.chdir("/Users/cyrus/Documents/Personal/Advancement/Python/Data")
print os.getcwd(); # Prints the working directory
# Out:
# /Users/cyrus/Documents/Personal/Advancement/Python/Data

# %% [markdown]
# ## Load the Datasets

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ### Histogram

# %%
plt.hist(train['SalePrice'])
plt.title("Sales Price Distribuion")
plt.xlabel("Value")
plt.ylabel("Frequency")
fig = plt.gcf()

# %%
plt.hist(train['LotArea'])
plt.title("Lot Area Distribuion")
plt.xlabel("Value")
plt.ylabel("Frequency")
fig = plt.gcf()

# %%
train['SalePrice'].plot.hist(grid=True, bins=20, rwidth=0.9,
                   color='#607c8e')
plt.title('Sales Price Distribuion')
plt.xlabel('Prices')
plt.ylabel('Count')
plt.grid(axis='y', alpha=0.75)

# %%
sns.set_style('darkgrid')
sns.distplot(train['SalePrice'])
# Out:
# /Users/cyrus/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
num_data = train[['MSSubClass','LotFrontage','LotArea','PoolArea','MiscVal','MoSold','YrSold','SalePrice','SaleCondition']]
num_data
# Out:
#       MSSubClass  LotFrontage  LotArea  PoolArea  MiscVal  MoSold  YrSold  \
# 0             60         65.0     8450         0        0       2    2008
# 1             20         80.0     9600         0        0       5    2007
# 2             60         68.0    11250         0        0       9    2008
# 3             70         60.0     9550         0        0       2    2006
# 4             60         84.0    14260         0        0      12    2008
# 5             50         85.0    14115         0      700      10    2009
# 6             20         75.0    10084         0        0       8    2007
# 7             60          NaN    10382         0      350      11    2009
# 8             50         51.0     6120         0        0       4    2008
# 9            190         50.0     7420         0        0       1    2008
# 10            20         70.0    11200         0        0       2    2008
# 11            60         85.0    11924         0        0       7    2006
# ...

# %%
num_data.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  PoolArea  MiscVal  MoSold  YrSold  \
# 0          60         65.0     8450         0        0       2    2008
# 1          20         80.0     9600         0        0       5    2007
# 2          60         68.0    11250         0        0       9    2008
# 3          70         60.0     9550         0        0       2    2006
# 4          60         84.0    14260         0        0      12    2008
#
#    SalePrice SaleCondition
# 0     208500        Normal
# 1     181500        Normal
# 2     223500        Normal
# 3     140000       Abnorml
# 4     250000        Normal

# %% [markdown]
# #### Visualizing the multidimensional relationships among the samples is as easy as calling sns.pairplot:

# %%
sns.pairplot(num_data, hue='SaleCondition', size=2.2);
# Out:
# /Users/cyrus/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# /Users/cyrus/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# /Users/cyrus/anaconda2/lib/python2.7/site-packages/numpy/lib/function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/cyrus/anaconda2/lib/python2.7/site-packages/numpy/lib/function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# #### Faceted histograms

# %%
grid = sns.FacetGrid(train, row="SaleCondition", col="YrSold", margin_titles=True)
grid.map(plt.hist, "SalePrice");

# %% [markdown]
# #### Factor plots

# %%
with sns.axes_style(style='ticks'):
    g = sns.factorplot("YrSold", "SalePrice", "SaleCondition", data=train, kind="box")
    g.set_axis_labels("Sales Condition", "Sales Price");

# %% [markdown]
# #### Joint distributions

# %%
with sns.axes_style('white'):
    sns.jointplot("SalePrice", "MoSold", data=train, kind='hex')
# Out:
# /Users/cyrus/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/cyrus/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
with sns.axes_style('white'):
    sns.jointplot("SalePrice", "YrSold", data=train, kind='hex')
# Out:
# /Users/cyrus/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/cyrus/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot("SalePrice", "MoSold", data=train, kind='reg');
# Out:
# /Users/cyrus/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/cyrus/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### Bar plots

# %%
with sns.axes_style('white'):
    g = sns.factorplot("YrSold", data=train, aspect=2,
                       kind="count", color='steelblue')
    g.set_xticklabels(step=1)

# %%
with sns.axes_style('white'):
    g = sns.factorplot("SaleCondition", data=train, aspect=2,
                       kind="count", color='steelblue')
    g.set_xticklabels(step=1)

# %%
with sns.axes_style('white'):
    g = sns.factorplot("SaleType", data=train, aspect=2,
                       kind="count", color='steelblue')
    g.set_xticklabels(step=1)

# %%
with sns.axes_style('white'):
    g = sns.factorplot("YrSold", data=train, aspect=4.0, kind='count',
                       hue='SaleCondition', order=range(2006, 2010))
    g.set_ylabels('Sales Condition Count')

# %%
with sns.axes_style('white'):
    g = sns.factorplot("MoSold", data=train, aspect=4.0, kind='count',
                       hue='SaleCondition')
    g.set_ylabels('Sales Condition Count')

# %%
tra
